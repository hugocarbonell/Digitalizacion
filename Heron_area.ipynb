# %% [markdown]
# <a href="https://colab.research.google.com/github/hugocarbonell/Digitalizacion/blob/main/Heron_area.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Cálculo del área de un triángulo
# Usando la fórmula de Herón, calculamos el área de cualquier triángulo conociendo la longitud de sus tres lados. Debes escribir un programa que te pida los tres lados y que calcule el área.
#
#
# > Cálculo del semiperímetro: $s = \frac{a+b+c}{2}$
#
# > Cálculo del área: $área = \sqrt{s(s-a)(s-b)(s-c)}$

# %%
#Pedimos el valor entero de cada uno de los lados
ladoA = int(input("Dime el valor del lado A:"))
ladoB = int(input("Dime el valor del lado B:"))
ladoC = int(input("Dime el valor del lado C:"))
#Cálculo del semiperímetro
s= (ladoA+ladoB+ladoC)/2
#Cálculo del área
área= (s*(s-ladoA)*(s-ladoB)*(s-ladoC))**(0.5)
#Imprimimos el resultado
print("El semiperímetro es=",s)
print("El área es=",área)
# Out:
# Dime el valor del lado A:7
# Dime el valor del lado B:12
# Dime el valor del lado C:9
# El semiperímetro es= 14.0
# El área es= 31.304951684997057
